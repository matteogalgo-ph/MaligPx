# %%
# %pip install anndata
# Out:
# ...
#   Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.2 MB 4.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.2 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.2 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 5.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 5.1 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/12.6 MB 5.6 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.6 MB 6.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.6 MB 6.0 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.6 MB 6.2 MB/s eta 0:00:01
# ...
